# %%
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
kernels = np.loadtxt('/home/rneveux/kernels_EFT/bk/z0.8/lnAs/Omfid.31377/test/000/bk_kernels_0.txt')
k = np.loadtxt('/home/swang/share/rneveux/FirstGenMocks_AbacusSummit/CubicBox/LRG/z0.800/stable/bispec/bk000_CubicBox_rsd_phmean_k')

# %%
kernels.shape
# Out:
# (76, 20)

# %%
for i in range(76):
    plt.plot(k, k**2*kernels[i])
