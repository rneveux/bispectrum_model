# %%
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]

# %%
data = np.load('/home/rneveux/data/BOSS/SGC/pk0pk2pk4bk000_DR12SGC-COMPSAM_V6C_0.50z0.75.npz')

# %%
data_pk = np.load('/home/rneveux/data/BOSS/cov_2048_BOSS_DR12_NGC_z3.npy', allow_pickle=True).item()

# %%
list(data)
# Out:
# ['data_bin_centres',
#  'data_bin_coords',
#  'data_bin_counts',
#  'data_vectors',
#  'data_vectors_shotnoise']

# %%
repo = '/home/rneveux/mocks/BOSS/SGC/0.50z0.75/'
pk0_n = 'pk0_DR12SGC-COMPSAM_V6C_mean_0.50z0.75.txt'
pk2_n = 'pk2_DR12SGC-COMPSAM_V6C_mean_0.50z0.75.txt'
pk4_n = 'pk4_DR12SGC-COMPSAM_V6C_mean_0.50z0.75.txt'
bk000_n = 'bk000_DR12SGC-COMPSAM_V6C_mean_0.50z0.75.txt'

pk0 = np.zeros((40,2))
pk2 = np.zeros((40,2))
pk4 = np.zeros((40,2))
bk000 = np.zeros((40,2))

pk0[:,0] = data['data_bin_coords'][:40]
pk2[:,0] = data['data_bin_coords'][40:80]
pk4[:,0] = data['data_bin_coords'][80:120]
bk000[:,0] = data['data_bin_coords'][120:160]

m=[]
for i in range(4):
    m.append(np.mean(np.real(data['data_vectors'][:,i*40:(i+1)*40]-data['data_vectors_shotnoise'][:,i*40:(i+1)*40]),axis=0))

pk0[:,1] = m[0]
pk2[:,1] = m[1]
pk4[:,1] = m[2]
bk000[:,1] = m[3]
np.savetxt(repo+pk0_n,pk0)
np.savetxt(repo+pk2_n,pk2)
np.savetxt(repo+pk4_n,pk4)
np.savetxt(repo+bk000_n,bk000)

# %%
a = np.loadtxt(repo+pk0_n)

# %%
plt.plot(a[:,0],a[:,0]*a[:,1],color='k')
plt.plot(pk2[:,0],pk2[:,0]*pk2[:,1],color='k')
plt.plot(pk4[:,0],pk4[:,0]*pk4[:,1],color='k')

# %%
plt.plot(bk000[:,0],bk000[:,0]**2*bk000[:,1],color='k')

# %%
k = data['data_bin_coords'][:40]
for i in range(4):
    m = np.mean(np.real(data['data_vectors'][:,i*40:(i+1)*40]-data['data_vectors_shotnoise'][:,i*40:(i+1)*40]),axis=0)
    s = np.std(np.real(data['data_vectors'][:,i*40:(i+1)*40]-data['data_vectors_shotnoise'][:,i*40:(i+1)*40]),axis=0)
    if i==3:
        plt.plot(k,k**2*m,color='k')
        plt.fill_between(k,k**2*(m-s),k**2*(m+s),color='k',alpha=.3)
    else:
        plt.plot(k,k*m,color='k')
        plt.fill_between(k,k*(m-s),k*(m+s),color='k',alpha=.3)
    plt.show()

# %%
cov = np.cov(np.real(data['data_vectors']-data['data_vectors_shotnoise']),rowvar=False)
#corr = np.corrcoef(np.real(data['data_vectors']-data['data_vectors_shotnoise']),rowvar=False)
corr = np.corrcoef(np.real(data['data_vectors']),rowvar=False)

# %%
cov.shape
# Out:
# (160, 160)

# %%
plt.matshow(cov)
plt.colorbar()

# %%
plt.plot(np.arange(len(corr)),corr[8])

# %%
plt.matshow(np.diag(corr[:40,120:160]))
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_504706/2280099666.py in <cell line: 1>()
# ----> 1 plt.matshow(np.diag(corr[:40,120:160]))
#       2 plt.colorbar()
#
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py in matshow(A, fignum, **kwargs)
#    2190         # Extract actual aspect ratio of array and make appropriately sized
#    2191         # figure.
# -> 2192         fig = figure(fignum, figsize=figaspect(A))
#    2193         ax = fig.add_axes([0.15, 0.09, 0.775, 0.775])
#    2194     im = ax.matshow(A, **kwargs)
#
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/matplotlib/figure.py in figaspect(arg)
#    3259     # Extract the aspect ratio of the array
#    3260     if isarray:
# -> 3261         nr, nc = arg.shape[:2]
#    3262         arr_ratio = nr / nc
#    3263     else:
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
plt.matshow(data_pk['cov'])
plt.colorbar()

# %%
t = data_pk['cov']/np.sqrt(np.diag(data_pk['cov'])[:, np.newaxis])/np.sqrt(np.diag(data_pk['cov']))

# %%
plt.plot(np.arange(120),data_pk['cov'][20])

# %%
data_pk['cov']
# Out:
# array([[1.52310492e+08, 1.78531479e+07, 6.76086859e+05, ...,
#         3.07157988e+04, 2.37781740e+04, 3.09638656e+04],
#        [1.78531479e+07, 3.46851336e+07, 4.08051349e+06, ...,
#         1.02080994e+04, 2.34164718e+04, 8.73180596e+03],
#        [6.76086859e+05, 4.08051349e+06, 1.02974898e+07, ...,
#         5.05466425e+03, 8.62354139e+03, 1.09092847e+03],
#        ...,
#        [3.07157988e+04, 1.02080994e+04, 5.05466425e+03, ...,
#         5.73482329e+03, 1.61377949e+03, 5.14511453e+02],
#        [2.37781740e+04, 2.34164718e+04, 8.62354139e+03, ...,
#         1.61377949e+03, 5.71865295e+03, 1.52372868e+03],
#        [3.09638656e+04, 8.73180596e+03, 1.09092847e+03, ...,
#         5.14511453e+02, 1.52372868e+03, 5.21243062e+03]])

# %%
t
# Out:
# array([[1.        , 0.24562819, 0.01707151, ..., 0.03286525, 0.02547808,
#         0.03475123],
#        [0.24562819, 1.        , 0.21591233, ..., 0.02288828, 0.05257786,
#         0.02053583],
#        [0.01707151, 0.21591233, 1.        , ..., 0.02080016, 0.03553637,
#         0.0047088 ],
#        ...,
#        [0.03286525, 0.02288828, 0.02080016, ..., 1.        , 0.28179761,
#         0.09410547],
#        [0.02547808, 0.05257786, 0.03553637, ..., 0.28179761, 1.        ,
#         0.27908766],
#        [0.03475123, 0.02053583, 0.0047088 , ..., 0.09410547, 0.27908766,
#         1.        ]])

# %%
plt.plot(np.arange(120),t[20])
plt.plot(np.arange(160),corr[20])

# %%
plt.matshow(t)
plt.colorbar()

# %%
plt.matshow(corr[:120,:120])
plt.colorbar()
